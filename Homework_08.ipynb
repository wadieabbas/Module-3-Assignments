# %% [markdown]
# ## Homework 08: Classification
#
# ### Due: Midnight, March 22nd (with usual 2 hour grace period and late policy)
#
# ### Overview
#
# In this final homework before starting our course project, we will introduce the essential machine learning paradigm of **classification**. We will work with the **UCI Adult** dataset. This is a binary classification task.
#
# As we’ve discussed in this week’s lessons, the classification workflow is similar to what we’ve done for regression, with a few key differences:
# - We use `StratifiedKFold` instead of plain `KFold` so that every fold keeps the original class proportions.
# - We use classification metrics (e.g., accuracy, precision, recall, F1-score for binary classification) instead of regression metrics.
# - We could explore misclassified instances through a confusion matrix (though we will not do that in this homework).
#
# For this assignment, you’ll build a gradient boosting classification using `HistGradientBoostingClassifier` (HGBC) and explore ways of tuning the hyperparameters, including using the technique of early stopping, which basically avoiding have to tune the number of estimators (called `max_iter` in HGBC).
#
# HGBC has many advantages, which we explain below.
#
#
# ### Grading
#
# There are 7 graded problems, each worth 7 points, and you get 1 point free if you complete the assignment.

# %%
# General utilities
import os
import io
import time
import zipfile
import requests
from collections import Counter

# Data handling and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import display
 
# Data source
from sklearn.datasets import fetch_openml

 
# scikit-learn core tools 
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    RandomizedSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder

 
# Import model 
from sklearn.ensemble import HistGradientBoostingClassifier
 
# Metrics
from sklearn.metrics import balanced_accuracy_score, classification_report
 
# Distributions for random search
from scipy.stats import loguniform, randint, uniform

# pandas dtypes helpers
from pandas.api.types import is_numeric_dtype, is_categorical_dtype
from pandas import CategoricalDtype

# Optuna Hyperparameter Search tool    (may need to be installed)
import optuna


# Misc

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ### Prelude 1: Load and Preprocess the UCI Adult Income Dataset
#
# - Load the dataset from sklearn
# - Preliminary EDA
# - Feature Engineering

# %%
# Load and clean
df = fetch_openml(name='adult', version=2, as_frame=True).frame

df.replace("?", np.nan, inplace=True)            # Some datasets use ? instead of Nan for missing data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
#  14  class           48842 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 2.7 MB

# %% [markdown]
# #### Check: Is the dataset imbalanced?

# %%
print(df['class'].value_counts(normalize=True))
# Out:
# class
# <=50K    0.760718
# >50K     0.239282
# Name: proportion, dtype: float64

# %% [markdown]
# **YES:** It looks like this dataset is somewhat imbalanced. Therefore, we will
# 1. Tell the model to compensate during training by setting `class_weight='balanced'` when defining the model;
# 2. Evaluate it `balanced_accuracy` instead of `accuracy` and with class-aware metrics (precision, recall, F1); and
# 3. [Optional] Adjust the probability threshold instead of relying on raw accuracy alone after examining the precision-recall trade-off you observe at 0.5.

# %% [markdown]
# ### Feature Engineering
#
# Based on the considerations in **Appendix One**, we'll make the following changes to the dataset to facilitate training:
#
#
# 1. Drop `fnlwgt` and `education`.
# 3. Replace `capital-gain` and `capital-loss` by their difference `capital_net` and add a log-scaled version `capital_net_log`.

# %%
# Drop the survey-weight column
df_eng = df.drop(columns=["fnlwgt"])

# Keep only the ordinal education feature
df_eng = df_eng.drop(columns=["education"])      # retain 'education-num'

# Combine capital gains and losses, add a log-scaled variant
df_eng["capital_net"]     = df_eng["capital-gain"] - df_eng["capital-loss"]
df_eng["capital_net_log"] = np.log1p(df_eng["capital_net"].clip(lower=0))
df_eng = df_eng.drop(columns=["capital-gain", "capital-loss"])

# check
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  category
#  2   education-num    48842 non-null  int64
#  3   marital-status   48842 non-null  category
#  4   occupation       46033 non-null  category
#  5   relationship     48842 non-null  category
#  6   race             48842 non-null  category
#  7   sex              48842 non-null  category
#  8   hours-per-week   48842 non-null  int64
#  9   native-country   47985 non-null  category
#  10  class            48842 non-null  category
#  11  capital_net      48842 non-null  int64
#  12  capital_net_log  48842 non-null  float64
# dtypes: category(8), float64(1), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# #### Separate target and split
#
# Create the feature set `X` and the target set `y` (using `class` as the target) and split the dataset into 80% training and 20% testing sets, making sure to stratify.

# %%
X = df_eng.drop(columns=["class"])
y = (df_eng["class"] == ">50K").astype(int)

# Split (with stratification)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y                           # So same proportion of classes in train and test sets
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (39073, 12) (39073,)
# Test : (9769, 12) (9769,)

# %% [markdown]
# ### Prelude 2: Create a data pipeline and the `HistGradientBoostingClassifier` model
#
# Histogram-based gradient boosting improves on the standard version by:
#
# * **Histogram splits:** bins each feature into ≤ `max_bins` quantiles (i.e., each bin is approximately the same size) and tests splits only between bins, slashing compute time and scaling to large data sets. Default for `max_bins` = 255.
# * **Native NaN handling:** treats missing values as their own bin—no imputation needed.
# * **Native Categorical Support**: accepts integer-encoded categories directly and tests “category c vs. all others” splits, eliminating one-hot blow-ups and fake orderings.
# * **Built-in early stopping:** stops training after no improvement in validation loss after `n_iter_no_change` rounds. `tol` defines "improvement" (default is 1e-7).
# * **Leaf shrinkage:** adds `l2_regularization`, which ridge-shrinks each leaf value (without changing tree shape) so tiny, noisy leaves have less effect.
#
# >**Summary:**  Histogram-based GB trades a tiny approximation error (binning) for a **huge speed-up** and adds extra conveniences, making it the preferred choice for large tabular data sets. Tuning workflow relies on **Early stopping** to stop training before overfitting occurs.

# %%
# Define a baseline model 

HGBC_model = HistGradientBoostingClassifier(
    # tree structure and learning rate
    learning_rate=0.1,            # These 5 parameters are at defaults for our baseline training in Problem 1             
    max_leaf_nodes=31,            # but will be tuned by randomized search in Problem 2 and Optuna in Problem 3               
    max_depth=None,               
    min_samples_leaf=20,          
    l2_regularization=0.0,        

    # bins and iteration
    max_bins=255,                 # default
    max_iter=500,                 # high enough for early stopping
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,      # 20% monitored for early stopping
    tol=1e-7,                     # default tolerance for validation improvement

    # class imbalance
    class_weight="balanced",

    random_state=random_seed,
    verbose=0
)

# %% [markdown]
# ### Create a pipeline appropriate for HGBC
#
# **Why use a `Pipeline` instead of encoding in the dataset first?**
#
# * **Avoid data leakage.** In each CV fold, the `OrdinalEncoder` is refit only on that fold’s training data, so the validation split never influences the encoder.
# * **Single, reusable object.** The pipeline bundles preprocessing + model, letting you call `fit`/`predict` on raw data anywhere (CV, Optuna, production) with identical behavior.
# * **Compatible with search tools.** `cross_validate`, `GridSearchCV`, and Optuna expect an estimator that can be cloned and refit; a pipeline meets that requirement automatically.
#
# Put simply, the pipeline gives you leak-free evaluation and portable, hassle-free tuning without extra code.

# %%
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",   # Allow unseen categories during transform
    unknown_value=-1,                     # Code for unseen categories
    encoded_missing_value=-2,             # Code for missing values (NaN)
    dtype=np.int64                        # Needed for HistGradientBoostingClassifier
)

# Categorical features
cat_cols = X.select_dtypes(exclude=["number"]).columns.tolist()

# Numeric features (everything that isn’t object / category)
num_cols = X.select_dtypes(include=["number"]).columns.tolist()

preprocess = ColumnTransformer(
    [("cat", enc, cat_cols),
     ("num", "passthrough", num_cols)]
)

pipelined_model = Pipeline([
    ("prep", preprocess),
    ("gb",   HGBC_model)
])

# %% [markdown]
# ## Problem 1: Baseline Cross-Validation with F1
#
# In this problem, you will run a baseline cross-validation evaluation of your `HistGradientBoostingClassifier` pipeline, using `HGBC_model` defined above.
#
# **Background:**
#
# * Since the Adult dataset is imbalanced (about 24% positives, 76% negatives), accuracy alone is not reliable.
# * We will use the **F1 score** as the evaluation metric, since it balances precision (avoiding false positives) and recall (avoiding false negatives) in a single measure. This is a fairer metric for imbalanced classification, where both types of error matter.
# * We will apply **5-fold stratified cross-validation** to make sure each fold has the same proportion of the classes as the original dataset.
# * Repeated cross-validation is optional and not required here, because the Adult dataset is large and `HistGradientBoostingClassifier` is robust to small sampling differences.
#
# **Instructions:**
#
# 1. Set up a `StratifiedKFold` cross-validation object with 5 splits, shuffling enabled, and `random_state=random_seed`.
# 2. Use `cross_val_score` to estimate the mean F1 score and its standard deviation across the folds.
# 3. Print out the mean and standard deviation of the F1 score, rounded to 4 decimal places.
# 4. Answer the graded question.

# %%
skfold = StratifiedKFold(n_splits=5, random_state=random_seed, shuffle=True)

hgbc_f1_score = cross_val_score(
        pipelined_model, 
        X_train, y_train,
        scoring='f1',
        cv=skfold, 
        n_jobs=-1
    )
    
mean_f1_score = np.mean(hgbc_f1_score)
std_f1_score  = np.std(hgbc_f1_score)

print(f"Mean F1 Score: {mean_f1_score:.4f}")
print(f"F1 Score STD: {std_f1_score:.4f}")
# Out:
# Mean F1 Score: 0.7123
# F1 Score STD: 0.0035

# %% [markdown]
# ### Problem 1 Graded Answer
#
# Set `a1` to the mean F1 score of the baseline model.

# %%
 # Your answer here

a1 = mean_f1_score

# %%
# DO NOT change this cell in any way

print(f'a1 = {a1:.4f}')
# Out:
# a1 = 0.7123

# %% [markdown]
# ## Problem 2: Hyperparameter Optimization with Randomized Search for F1
#
# In this problem, you will tune your `pipelined_model` using `RandomizedSearchCV` to identify the best combination of tree structure and learning rate parameters that maximize the **F1 score**.
#
# **Background:**
# The F1 score is our main metric because it balances precision and recall on an imbalanced dataset. Optimizing hyperparameters for F1 ensures we manage both false positives and false negatives in a single measure.
#
# **Instructions:**
#
# 1. Set up a randomized search over the following hyperparameter ranges, using appropriate random-number distributions:
#
#    * `learning_rate` (log-uniform between 1e-3 and 0.3)
#    * `max_leaf_nodes` (integer from 16 to 256)
#    * `max_depth` (integer from 2 to 10)
#    * `min_samples_leaf` (integer from 10 to 200)
#    * `l2_regularization` (uniform between 0.0 and 2.0)
# 2. Use **5-fold stratified cross-validation**, with the same settings as in Problem 1.
# 3. Start `n_iter` at 10 or 20 to prototype, but try for 50 - 100 trials. More trials will generally yield better results, if your time and machine allow.
# 4. After running the search, show a neatly formatted table of the top 5 results, using `display(...)` showing their mean F1 scores, standard deviation, and the chosen hyperparameter values.
# 5. Answer the graded question.

# %%
skfold = StratifiedKFold(n_splits=5, random_state=random_seed, shuffle=True)

# number of iterations for random search
n_iterations = 100

# parameter distributions for random search
param_distributions = {
    'gb__learning_rate': loguniform(1e-3, 0.3), 
    'gb__max_leaf_nodes': randint(16, 257),     
    'gb__max_depth': randint(2, 11),            
    'gb__min_samples_leaf': randint(10, 201),   
    'gb__l2_regularization': uniform(0.0, 2.0)
}

# set up randomized search with 5-fold stratified cross-validation repeated 3 times
random_search = RandomizedSearchCV(
    estimator           = pipelined_model,
    param_distributions = param_distributions,
    n_iter              = n_iterations,                                                       
    cv                  = skfold,
    random_state        = random_seed,
    n_jobs              = -1,        
    verbose             = 1,
    scoring             = 'f1_macro'
)

random_search.fit(X_train, y_train)

# Extract top 5 results
results = pd.DataFrame(random_search.cv_results_).sort_values(
    by='mean_test_score', ascending=False
).head(5)

# Display relevant columns
display(results[[
    'mean_test_score', 'std_test_score', 'param_gb__learning_rate',
    'param_gb__max_leaf_nodes', 'param_gb__max_depth',
    'param_gb__min_samples_leaf', 'param_gb__l2_regularization'
]])
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#     mean_test_score  std_test_score  param_gb__learning_rate  \
# 19         0.796895        0.002572                 0.127541
# 60         0.796715        0.003054                 0.268164
# 21         0.796330        0.002852                 0.157664
# 0          0.796234        0.003462                 0.226482
# 59         0.796168        0.003025                 0.229549
#
#     param_gb__max_leaf_nodes  param_gb__max_depth  param_gb__min_samples_leaf  \
# 19                        48                    3                          57
# 60                       206                    5                         169
# 21                       242                    2                         110
# 0                        204                    9                          30
# 59                        61                    2                         190
#
#     param_gb__l2_regularization
# 19                     1.829919
# 60                     1.144585
# 21                     1.275115
# 0                      0.749080
# 59                     1.495438

# %%
best_mean_f1_score = results['mean_test_score'].max()
best_mean_f1_score
# Out:
# np.float64(0.7968950997225985)

# %% [markdown]
# ### Problem 2 Graded Answer
#
# Set `a2` to the mean F1 score of the best model found.

# %%
 # Your answer here

a2 = best_mean_f1_score

# %%
# DO NOT change this cell in any way

print(f'a2 = {a2:.4f}')
# Out:
# a2 = 0.7969

# %% [markdown]
# ## Problem 3: Hyperparameter Optimization with Optuna for F1
#
# In this problem, you will explore **Optuna**, a powerful hyperparameter optimization framework, to identify the best combination of hyperparameters that maximize the F1 score of your `pipelined_model`.
#
# **Background:**
# Optuna uses a smarter sampling strategy than grid search or randomized search, allowing you to explore the hyperparameter space more efficiently. It also supports *pruning*, which can stop unpromising trials early to save time. This makes it a popular SOTA optimization tool.
#
# **Before you start** browse the [Optuna documentation](https://optuna.org) and view the [tutorial video](https://optuna.readthedocs.io/en/stable/tutorial/index.html).
#
# As before, we focus on the **F1 score** because it balances precision and recall, making it more robust on an imbalanced dataset.
#
# **Instructions:**
#
# 1. Define an Optuna objective function to optimize F1 score, sampling the exact same hyperparameter ranges you did in Problem 2 and using the same CV settings.
# 3. Set up an Optuna study with a reasonable number of trials (e.g., up to 100 depending on runtime resources--on my machine Optuna runs about 10x faster than randomized search for the same number of trials, but YMMV).
# 4. After running the optimization, `display` a clean table with the top 5 trials showing their F1 scores and corresponding hyperparameter settings.
# 5. Answer the graded question.
#
# **Note:**  There are many resources on Optuna you can find on the web, but for this problem, you have my permission to let ChatGPT write the code for you.

# %%
# Define the objective function
def objective(trial):
    # Suggest hyperparameters
    learning_rate = trial.suggest_float("gb__learning_rate", 1e-3, 0.3, log=True)
    max_leaf_nodes = trial.suggest_int("gb__max_leaf_nodes", 16, 256)
    max_depth = trial.suggest_int("gb__max_depth", 2, 10)
    min_samples_leaf = trial.suggest_int("gb__min_samples_leaf", 10, 200)
    l2_regularization = trial.suggest_float("gb__l2_regularization", 0.0, 2.0)
    
    # Set the hyperparameters in the pipeline
    pipelined_model.set_params(
        gb__learning_rate=learning_rate,
        gb__max_leaf_nodes=max_leaf_nodes,
        gb__max_depth=max_depth,
        gb__min_samples_leaf=min_samples_leaf,
        gb__l2_regularization=l2_regularization
    )
    
    # Perform cross-validation
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_seed)
    f1_scores = cross_val_score(
        pipelined_model, X_train, y_train, cv=cv, scoring="f1_macro", n_jobs=-1
    )
    
    # Return the mean F1 score
    return f1_scores.mean()

# Create the Optuna study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, n_jobs=-1)

# Display the top 5 trials
top_trials = pd.DataFrame([
    {
        "Trial": trial.number,
        "F1_Score": trial.value,
        **trial.params
    }
    for trial in study.trials
]).sort_values(by="F1_Score", ascending=False).head(5)
display(top_trials)
# Out:
# [I 2026-03-13 01:54:51,777] A new study created in memory with name: no-name-bd884c03-db94-40a9-b795-a1b4761341ed
# [I 2026-03-13 01:54:53,097] Trial 0 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.014663701463463142, 'gb__max_leaf_nodes': 180, 'gb__max_depth': 9, 'gb__min_samples_leaf': 142, 'gb__l2_regularization': 0.09933206810159079}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:53,120] Trial 1 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.0316316829828545, 'gb__max_leaf_nodes': 81, 'gb__max_depth': 10, 'gb__min_samples_leaf': 142, 'gb__l2_regularization': 0.17854929622027682}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:54,262] Trial 3 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.2351135696935308, 'gb__max_leaf_nodes': 165, 'gb__max_depth': 5, 'gb__min_samples_leaf': 82, 'gb__l2_regularization': 1.9473671583445697}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:54,300] Trial 2 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.08221086886129354, 'gb__max_leaf_nodes': 89, 'gb__max_depth': 9, 'gb__min_samples_leaf': 72, 'gb__l2_regularization': 0.19541898937430635}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:55,247] Trial 4 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.05548926024895248, 'gb__max_leaf_nodes': 166, 'gb__max_depth': 9, 'gb__min_samples_leaf': 94, 'gb__l2_regularization': 0.26693155520527223}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:55,378] Trial 5 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.0072525103890391535, 'gb__max_leaf_nodes': 54, 'gb__max_depth': 7, 'gb__min_samples_leaf': 194, 'gb__l2_regularization': 0.8417885064571915}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:55,495] Trial 10 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.0015272132218560708, 'gb__max_leaf_nodes': 143, 'gb__max_depth': 10, 'gb__min_samples_leaf': 161, 'gb__l2_regularization': 1.9738351527361964}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:56,497] Trial 8 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.11996222272265226, 'gb__max_leaf_nodes': 151, 'gb__max_depth': 3, 'gb__min_samples_leaf': 34, 'gb__l2_regularization': 0.11148136918224116}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:56,554] Trial 7 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.12547467529881273, 'gb__max_leaf_nodes': 22, 'gb__max_depth': 7, 'gb__min_samples_leaf': 146, 'gb__l2_regularization': 1.7687135885153003}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:57,521] Trial 11 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.07110175222394854, 'gb__max_leaf_nodes': 97, 'gb__max_depth': 2, 'gb__min_samples_leaf': 111, 'gb__l2_regularization': 1.9451461724904064}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:57,633] Trial 6 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.17108608385193924, 'gb__max_leaf_nodes': 230, 'gb__max_depth': 7, 'gb__min_samples_leaf': 133, 'gb__l2_regularization': 1.562286845457438}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:57,809] Trial 9 finished with value: 0.7911635452879077 and parameters: {'gb__learning_rate': 0.027212888404345017, 'gb__max_leaf_nodes': 86, 'gb__max_depth': 6, 'gb__min_samples_leaf': 33, 'gb__l2_regularization': 1.6016665837136461}. Best is trial 0 with value: 0.7911635452879077.
# [I 2026-03-13 01:54:59,917] Trial 12 finished with value: 0.7932049311988069 and parameters: {'gb__learning_rate': 0.020223535586838544, 'gb__max_leaf_nodes': 57, 'gb__max_depth': 7, 'gb__min_samples_leaf': 57, 'gb__l2_regularization': 1.4144930108799707}. Best is trial 12 with value: 0.7932049311988069.
# [I 2026-03-13 01:55:00,198] Trial 13 finished with value: 0.7897354273859584 and parameters: {'gb__learning_rate': 0.015965562131427982, 'gb__max_leaf_nodes': 170, 'gb__max_depth': 8, 'gb__min_samples_leaf': 134, 'gb__l2_regularization': 0.4843768802812993}. Best is trial 12 with value: 0.7932049311988069.
# [I 2026-03-13 01:55:00,869] Trial 15 finished with value: 0.795167137044298 and parameters: {'gb__learning_rate': 0.13796727595487374, 'gb__max_leaf_nodes': 164, 'gb__max_depth': 6, 'gb__min_samples_leaf': 118, 'gb__l2_regularization': 0.7468725499843865}. Best is trial 15 with value: 0.795167137044298.
# [I 2026-03-13 01:55:01,746] Trial 16 finished with value: 0.7957376021199221 and parameters: {'gb__learning_rate': 0.08947914922195115, 'gb__max_leaf_nodes': 61, 'gb__max_depth': 7, 'gb__min_samples_leaf': 125, 'gb__l2_regularization': 1.4766737030046355}. Best is trial 16 with value: 0.7957376021199221.
# [I 2026-03-13 01:55:02,387] Trial 18 finished with value: 0.7968949191342863 and parameters: {'gb__learning_rate': 0.188250555999569, 'gb__max_leaf_nodes': 229, 'gb__max_depth': 4, 'gb__min_samples_leaf': 17, 'gb__l2_regularization': 0.8775610407934908}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:02,600] Trial 17 finished with value: 0.7391804572980898 and parameters: {'gb__learning_rate': 0.002522993312666738, 'gb__max_leaf_nodes': 69, 'gb__max_depth': 3, 'gb__min_samples_leaf': 41, 'gb__l2_regularization': 1.9314311351089306}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:02,708] Trial 14 finished with value: 0.7795922161623832 and parameters: {'gb__learning_rate': 0.007989858491551295, 'gb__max_leaf_nodes': 194, 'gb__max_depth': 9, 'gb__min_samples_leaf': 135, 'gb__l2_regularization': 1.7069645132580444}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:04,360] Trial 19 finished with value: 0.738487753431871 and parameters: {'gb__learning_rate': 0.0014382569561600166, 'gb__max_leaf_nodes': 40, 'gb__max_depth': 5, 'gb__min_samples_leaf': 47, 'gb__l2_regularization': 1.5998312406906647}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:04,737] Trial 20 finished with value: 0.7949298445010143 and parameters: {'gb__learning_rate': 0.03490548906604899, 'gb__max_leaf_nodes': 216, 'gb__max_depth': 10, 'gb__min_samples_leaf': 150, 'gb__l2_regularization': 1.5613310096620145}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:06,265] Trial 21 finished with value: 0.7638687093168672 and parameters: {'gb__learning_rate': 0.005850972219951757, 'gb__max_leaf_nodes': 253, 'gb__max_depth': 5, 'gb__min_samples_leaf': 190, 'gb__l2_regularization': 0.749942329817689}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:07,325] Trial 22 finished with value: 0.7892310080478991 and parameters: {'gb__learning_rate': 0.014038018788611583, 'gb__max_leaf_nodes': 218, 'gb__max_depth': 10, 'gb__min_samples_leaf': 177, 'gb__l2_regularization': 0.6344072665766165}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:08,860] Trial 23 finished with value: 0.7849809012893623 and parameters: {'gb__learning_rate': 0.010340270543996333, 'gb__max_leaf_nodes': 217, 'gb__max_depth': 10, 'gb__min_samples_leaf': 178, 'gb__l2_regularization': 0.6009987527520899}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:09,548] Trial 25 finished with value: 0.7785683579247025 and parameters: {'gb__learning_rate': 0.01021402250412846, 'gb__max_leaf_nodes': 207, 'gb__max_depth': 5, 'gb__min_samples_leaf': 61, 'gb__l2_regularization': 1.1570476744488254}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:10,125] Trial 24 finished with value: 0.7801262437040675 and parameters: {'gb__learning_rate': 0.007366621288702802, 'gb__max_leaf_nodes': 214, 'gb__max_depth': 8, 'gb__min_samples_leaf': 55, 'gb__l2_regularization': 1.0914083605859304}. Best is trial 18 with value: 0.7968949191342863.
# [I 2026-03-13 01:55:10,808] Trial 28 finished with value: 0.797065544577524 and parameters: {'gb__learning_rate': 0.2682575489571532, 'gb__max_leaf_nodes': 237, 'gb__max_depth': 4, 'gb__min_samples_leaf': 14, 'gb__l2_regularization': 1.211374185632776}. Best is trial 28 with value: 0.797065544577524.
# [I 2026-03-13 01:55:11,025] Trial 26 finished with value: 0.7540070329906081 and parameters: {'gb__learning_rate': 0.0035854903353161557, 'gb__max_leaf_nodes': 239, 'gb__max_depth': 4, 'gb__min_samples_leaf': 58, 'gb__l2_regularization': 1.206823491926561}. Best is trial 28 with value: 0.797065544577524.
# [I 2026-03-13 01:55:11,238] Trial 29 finished with value: 0.7965265021589035 and parameters: {'gb__learning_rate': 0.2424776158910898, 'gb__max_leaf_nodes': 250, 'gb__max_depth': 4, 'gb__min_samples_leaf': 12, 'gb__l2_regularization': 1.188493775016775}. Best is trial 28 with value: 0.797065544577524.
# [I 2026-03-13 01:55:11,550] Trial 27 finished with value: 0.7665130136013495 and parameters: {'gb__learning_rate': 0.00598056826946289, 'gb__max_leaf_nodes': 212, 'gb__max_depth': 5, 'gb__min_samples_leaf': 112, 'gb__l2_regularization': 1.1544505256974444}. Best is trial 28 with value: 0.797065544577524.
# [I 2026-03-13 01:55:11,775] Trial 30 finished with value: 0.7962038864992242 and parameters: {'gb__learning_rate': 0.2667292270230773, 'gb__max_leaf_nodes': 237, 'gb__max_depth': 4, 'gb__min_samples_leaf': 176, 'gb__l2_regularization': 1.2802207574272877}. Best is trial 28 with value: 0.797065544577524.
# [I 2026-03-13 01:55:12,049] Trial 31 finished with value: 0.7963951123132393 and parameters: {'gb__learning_rate': 0.24540278187665251, 'gb__max_leaf_nodes': 116, 'gb__max_depth': 4, 'gb__min_samples_leaf': 189, 'gb__l2_regularization': 1.2575416209272223}. Best is trial 28 with value: 0.797065544577524.
# [I 2026-03-13 01:55:12,162] Trial 32 finished with value: 0.7987202222550611 and parameters: {'gb__learning_rate': 0.20315980522774246, 'gb__max_leaf_nodes': 255, 'gb__max_depth': 5, 'gb__min_samples_leaf': 13, 'gb__l2_regularization': 1.0656778650741574}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:12,406] Trial 33 finished with value: 0.7966229915243851 and parameters: {'gb__learning_rate': 0.2994784007919803, 'gb__max_leaf_nodes': 126, 'gb__max_depth': 4, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.1551890405715297}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:12,542] Trial 34 finished with value: 0.7969922809545296 and parameters: {'gb__learning_rate': 0.2962639154805479, 'gb__max_leaf_nodes': 103, 'gb__max_depth': 4, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.1552650326500022}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:12,722] Trial 35 finished with value: 0.7953354438104684 and parameters: {'gb__learning_rate': 0.2856277170312447, 'gb__max_leaf_nodes': 117, 'gb__max_depth': 4, 'gb__min_samples_leaf': 114, 'gb__l2_regularization': 1.180648576179496}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:12,894] Trial 36 finished with value: 0.7965400539865637 and parameters: {'gb__learning_rate': 0.24418980628826148, 'gb__max_leaf_nodes': 131, 'gb__max_depth': 4, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.1664678305120268}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:13,094] Trial 37 finished with value: 0.796632601007266 and parameters: {'gb__learning_rate': 0.2675060243932513, 'gb__max_leaf_nodes': 115, 'gb__max_depth': 4, 'gb__min_samples_leaf': 14, 'gb__l2_regularization': 1.3536432238945946}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:13,430] Trial 39 finished with value: 0.7973777216902861 and parameters: {'gb__learning_rate': 0.2592501973172251, 'gb__max_leaf_nodes': 256, 'gb__max_depth': 4, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.3420243750786964}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:13,450] Trial 38 finished with value: 0.7965378406814958 and parameters: {'gb__learning_rate': 0.21181084924553642, 'gb__max_leaf_nodes': 254, 'gb__max_depth': 4, 'gb__min_samples_leaf': 13, 'gb__l2_regularization': 1.2320223839136015}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:13,745] Trial 40 finished with value: 0.7964940164273969 and parameters: {'gb__learning_rate': 0.23817871691268186, 'gb__max_leaf_nodes': 253, 'gb__max_depth': 4, 'gb__min_samples_leaf': 11, 'gb__l2_regularization': 1.2788617481869604}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:13,812] Trial 41 finished with value: 0.7961274717950231 and parameters: {'gb__learning_rate': 0.2956765011533782, 'gb__max_leaf_nodes': 117, 'gb__max_depth': 4, 'gb__min_samples_leaf': 14, 'gb__l2_regularization': 0.9175001005607375}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:14,146] Trial 42 finished with value: 0.795620963964635 and parameters: {'gb__learning_rate': 0.28568318448226876, 'gb__max_leaf_nodes': 256, 'gb__max_depth': 4, 'gb__min_samples_leaf': 12, 'gb__l2_regularization': 1.3226655805618064}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:14,161] Trial 43 finished with value: 0.7969160038750424 and parameters: {'gb__learning_rate': 0.29147378394862, 'gb__max_leaf_nodes': 113, 'gb__max_depth': 4, 'gb__min_samples_leaf': 11, 'gb__l2_regularization': 0.9742805076601881}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:14,744] Trial 44 finished with value: 0.7967565295362817 and parameters: {'gb__learning_rate': 0.1700337441530189, 'gb__max_leaf_nodes': 254, 'gb__max_depth': 3, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 0.9726344224730423}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:14,956] Trial 45 finished with value: 0.7964656365348257 and parameters: {'gb__learning_rate': 0.17446999412374722, 'gb__max_leaf_nodes': 195, 'gb__max_depth': 3, 'gb__min_samples_leaf': 17, 'gb__l2_regularization': 0.9620725621463253}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:15,289] Trial 46 finished with value: 0.796578450536729 and parameters: {'gb__learning_rate': 0.17607641939742782, 'gb__max_leaf_nodes': 102, 'gb__max_depth': 3, 'gb__min_samples_leaf': 21, 'gb__l2_regularization': 0.9550903424299367}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:15,592] Trial 47 finished with value: 0.7962069136489444 and parameters: {'gb__learning_rate': 0.1730650524261628, 'gb__max_leaf_nodes': 195, 'gb__max_depth': 3, 'gb__min_samples_leaf': 24, 'gb__l2_regularization': 0.9932451341982136}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:16,402] Trial 48 finished with value: 0.7940629120937256 and parameters: {'gb__learning_rate': 0.05498219232783561, 'gb__max_leaf_nodes': 189, 'gb__max_depth': 3, 'gb__min_samples_leaf': 23, 'gb__l2_regularization': 0.9776625338703984}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:16,905] Trial 49 finished with value: 0.7934444689987507 and parameters: {'gb__learning_rate': 0.04931169330786857, 'gb__max_leaf_nodes': 193, 'gb__max_depth': 3, 'gb__min_samples_leaf': 27, 'gb__l2_regularization': 1.0153660675233385}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:17,109] Trial 50 finished with value: 0.7971048618377392 and parameters: {'gb__learning_rate': 0.17478839417919936, 'gb__max_leaf_nodes': 190, 'gb__max_depth': 3, 'gb__min_samples_leaf': 26, 'gb__l2_regularization': 0.9401253497382323}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:17,520] Trial 51 finished with value: 0.7971164570446069 and parameters: {'gb__learning_rate': 0.14865639025580776, 'gb__max_leaf_nodes': 196, 'gb__max_depth': 3, 'gb__min_samples_leaf': 28, 'gb__l2_regularization': 0.9887426280021316}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:17,799] Trial 52 finished with value: 0.7964491399840236 and parameters: {'gb__learning_rate': 0.1615802341546935, 'gb__max_leaf_nodes': 192, 'gb__max_depth': 3, 'gb__min_samples_leaf': 27, 'gb__l2_regularization': 0.9604968215361614}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:18,145] Trial 53 finished with value: 0.7969557965255682 and parameters: {'gb__learning_rate': 0.16184600570816352, 'gb__max_leaf_nodes': 229, 'gb__max_depth': 3, 'gb__min_samples_leaf': 26, 'gb__l2_regularization': 0.8821864953863267}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:18,421] Trial 54 finished with value: 0.7968955269268234 and parameters: {'gb__learning_rate': 0.16569650202058392, 'gb__max_leaf_nodes': 239, 'gb__max_depth': 3, 'gb__min_samples_leaf': 27, 'gb__l2_regularization': 1.0076477837599989}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:18,829] Trial 55 finished with value: 0.7968955269268234 and parameters: {'gb__learning_rate': 0.16846428218166343, 'gb__max_leaf_nodes': 99, 'gb__max_depth': 3, 'gb__min_samples_leaf': 24, 'gb__l2_regularization': 1.0393363508317903}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:19,410] Trial 56 finished with value: 0.796199583529555 and parameters: {'gb__learning_rate': 0.10041523453021645, 'gb__max_leaf_nodes': 96, 'gb__max_depth': 3, 'gb__min_samples_leaf': 27, 'gb__l2_regularization': 1.0558020424365488}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:19,944] Trial 57 finished with value: 0.7955423911235149 and parameters: {'gb__learning_rate': 0.09587844178416485, 'gb__max_leaf_nodes': 103, 'gb__max_depth': 2, 'gb__min_samples_leaf': 27, 'gb__l2_regularization': 1.4069099282883175}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:20,454] Trial 58 finished with value: 0.7956741298477156 and parameters: {'gb__learning_rate': 0.09738492164030718, 'gb__max_leaf_nodes': 79, 'gb__max_depth': 2, 'gb__min_samples_leaf': 29, 'gb__l2_regularization': 1.0624560148596085}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:20,797] Trial 59 finished with value: 0.7958217609967372 and parameters: {'gb__learning_rate': 0.09564353985575812, 'gb__max_leaf_nodes': 149, 'gb__max_depth': 2, 'gb__min_samples_leaf': 29, 'gb__l2_regularization': 1.0560516536151665}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:21,575] Trial 60 finished with value: 0.7964031686267815 and parameters: {'gb__learning_rate': 0.10350311065381626, 'gb__max_leaf_nodes': 148, 'gb__max_depth': 2, 'gb__min_samples_leaf': 30, 'gb__l2_regularization': 1.4018489831478191}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:21,804] Trial 61 finished with value: 0.7940818207472325 and parameters: {'gb__learning_rate': 0.10588670935981144, 'gb__max_leaf_nodes': 79, 'gb__max_depth': 2, 'gb__min_samples_leaf': 93, 'gb__l2_regularization': 0.8095902341751342}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:22,274] Trial 62 finished with value: 0.7951851544582292 and parameters: {'gb__learning_rate': 0.09604763366259889, 'gb__max_leaf_nodes': 149, 'gb__max_depth': 2, 'gb__min_samples_leaf': 31, 'gb__l2_regularization': 1.0656190208723293}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:22,658] Trial 63 finished with value: 0.7964135407559494 and parameters: {'gb__learning_rate': 0.09952141071101275, 'gb__max_leaf_nodes': 240, 'gb__max_depth': 5, 'gb__min_samples_leaf': 33, 'gb__l2_regularization': 0.8240631840748682}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:23,252] Trial 64 finished with value: 0.7981513332792034 and parameters: {'gb__learning_rate': 0.10137704417847841, 'gb__max_leaf_nodes': 230, 'gb__max_depth': 5, 'gb__min_samples_leaf': 42, 'gb__l2_regularization': 1.0679121878591327}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:23,481] Trial 65 finished with value: 0.7957366754046362 and parameters: {'gb__learning_rate': 0.1012743815869347, 'gb__max_leaf_nodes': 242, 'gb__max_depth': 2, 'gb__min_samples_leaf': 36, 'gb__l2_regularization': 1.4282728567058447}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:24,011] Trial 66 finished with value: 0.7950046788056369 and parameters: {'gb__learning_rate': 0.09284201579687872, 'gb__max_leaf_nodes': 156, 'gb__max_depth': 2, 'gb__min_samples_leaf': 38, 'gb__l2_regularization': 1.0702649706823175}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:24,526] Trial 67 finished with value: 0.795432464326865 and parameters: {'gb__learning_rate': 0.10350311523560826, 'gb__max_leaf_nodes': 150, 'gb__max_depth': 2, 'gb__min_samples_leaf': 38, 'gb__l2_regularization': 1.458657267595456}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:25,081] Trial 68 finished with value: 0.7958494693005761 and parameters: {'gb__learning_rate': 0.11879063558735387, 'gb__max_leaf_nodes': 149, 'gb__max_depth': 2, 'gb__min_samples_leaf': 41, 'gb__l2_regularization': 0.7569187858494704}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:25,494] Trial 70 finished with value: 0.7962855687997422 and parameters: {'gb__learning_rate': 0.12305128343360815, 'gb__max_leaf_nodes': 151, 'gb__max_depth': 6, 'gb__min_samples_leaf': 37, 'gb__l2_regularization': 0.7643894954640594}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:25,567] Trial 69 finished with value: 0.7962789388248163 and parameters: {'gb__learning_rate': 0.11630246161284623, 'gb__max_leaf_nodes': 149, 'gb__max_depth': 2, 'gb__min_samples_leaf': 38, 'gb__l2_regularization': 0.7720619072270098}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:26,125] Trial 72 finished with value: 0.7966998527063168 and parameters: {'gb__learning_rate': 0.12442043696221118, 'gb__max_leaf_nodes': 226, 'gb__max_depth': 5, 'gb__min_samples_leaf': 42, 'gb__l2_regularization': 0.8148949631245901}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:26,389] Trial 71 finished with value: 0.7960303383356283 and parameters: {'gb__learning_rate': 0.071339753760252, 'gb__max_leaf_nodes': 177, 'gb__max_depth': 5, 'gb__min_samples_leaf': 39, 'gb__l2_regularization': 0.8196020493839224}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:26,773] Trial 73 finished with value: 0.796575840543818 and parameters: {'gb__learning_rate': 0.1315957382946718, 'gb__max_leaf_nodes': 224, 'gb__max_depth': 5, 'gb__min_samples_leaf': 38, 'gb__l2_regularization': 0.8078082365872192}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:27,426] Trial 74 finished with value: 0.7950857691896239 and parameters: {'gb__learning_rate': 0.07503618679924437, 'gb__max_leaf_nodes': 229, 'gb__max_depth': 5, 'gb__min_samples_leaf': 39, 'gb__l2_regularization': 0.8341018609061293}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:27,569] Trial 75 finished with value: 0.7972587967024947 and parameters: {'gb__learning_rate': 0.06942023393590198, 'gb__max_leaf_nodes': 224, 'gb__max_depth': 6, 'gb__min_samples_leaf': 42, 'gb__l2_regularization': 0.6964441259418717}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:28,166] Trial 77 finished with value: 0.7960538642759248 and parameters: {'gb__learning_rate': 0.13828087116499924, 'gb__max_leaf_nodes': 223, 'gb__max_depth': 6, 'gb__min_samples_leaf': 44, 'gb__l2_regularization': 0.358264822085419}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:28,435] Trial 78 finished with value: 0.796527558788819 and parameters: {'gb__learning_rate': 0.13222340289038906, 'gb__max_leaf_nodes': 229, 'gb__max_depth': 6, 'gb__min_samples_leaf': 46, 'gb__l2_regularization': 1.49490159961741}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:28,557] Trial 76 finished with value: 0.7962689076497133 and parameters: {'gb__learning_rate': 0.07093303583933341, 'gb__max_leaf_nodes': 224, 'gb__max_depth': 6, 'gb__min_samples_leaf': 42, 'gb__l2_regularization': 0.7279229906314759}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:29,301] Trial 79 finished with value: 0.7968069026001695 and parameters: {'gb__learning_rate': 0.06843039809320356, 'gb__max_leaf_nodes': 226, 'gb__max_depth': 6, 'gb__min_samples_leaf': 45, 'gb__l2_regularization': 0.7190331460609308}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:29,651] Trial 80 finished with value: 0.7960648361636988 and parameters: {'gb__learning_rate': 0.06731546341801511, 'gb__max_leaf_nodes': 225, 'gb__max_depth': 6, 'gb__min_samples_leaf': 48, 'gb__l2_regularization': 0.6603080642702828}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:30,140] Trial 81 finished with value: 0.7963995792667973 and parameters: {'gb__learning_rate': 0.07499648128059747, 'gb__max_leaf_nodes': 224, 'gb__max_depth': 5, 'gb__min_samples_leaf': 48, 'gb__l2_regularization': 0.2647638294633895}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:30,584] Trial 83 finished with value: 0.7963561872674363 and parameters: {'gb__learning_rate': 0.14576593004657978, 'gb__max_leaf_nodes': 227, 'gb__max_depth': 6, 'gb__min_samples_leaf': 48, 'gb__l2_regularization': 0.6849088055953114}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:30,663] Trial 82 finished with value: 0.796202793619434 and parameters: {'gb__learning_rate': 0.06839966843970986, 'gb__max_leaf_nodes': 228, 'gb__max_depth': 5, 'gb__min_samples_leaf': 74, 'gb__l2_regularization': 0.6859390262915426}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:30,777] Trial 84 finished with value: 0.796376512439054 and parameters: {'gb__learning_rate': 0.20882978791033777, 'gb__max_leaf_nodes': 224, 'gb__max_depth': 6, 'gb__min_samples_leaf': 48, 'gb__l2_regularization': 0.8859222255608813}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:30,978] Trial 85 finished with value: 0.7959368972601827 and parameters: {'gb__learning_rate': 0.21172028833564102, 'gb__max_leaf_nodes': 232, 'gb__max_depth': 6, 'gb__min_samples_leaf': 70, 'gb__l2_regularization': 0.6532503809973956}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:31,112] Trial 86 finished with value: 0.795773398490843 and parameters: {'gb__learning_rate': 0.2082869228401943, 'gb__max_leaf_nodes': 205, 'gb__max_depth': 6, 'gb__min_samples_leaf': 68, 'gb__l2_regularization': 1.127653823478956}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:31,332] Trial 87 finished with value: 0.7957956382349481 and parameters: {'gb__learning_rate': 0.20770584464611822, 'gb__max_leaf_nodes': 206, 'gb__max_depth': 6, 'gb__min_samples_leaf': 50, 'gb__l2_regularization': 0.37760735243411253}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:31,572] Trial 88 finished with value: 0.7957748755811458 and parameters: {'gb__learning_rate': 0.21263179422781162, 'gb__max_leaf_nodes': 246, 'gb__max_depth': 6, 'gb__min_samples_leaf': 75, 'gb__l2_regularization': 0.600980025253968}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:31,803] Trial 89 finished with value: 0.7946321418368487 and parameters: {'gb__learning_rate': 0.2163874433427492, 'gb__max_leaf_nodes': 205, 'gb__max_depth': 6, 'gb__min_samples_leaf': 64, 'gb__l2_regularization': 0.6941544282185976}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:32,045] Trial 90 finished with value: 0.79500876325858 and parameters: {'gb__learning_rate': 0.20362213684616126, 'gb__max_leaf_nodes': 206, 'gb__max_depth': 7, 'gb__min_samples_leaf': 77, 'gb__l2_regularization': 0.6475813666746026}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:32,238] Trial 91 finished with value: 0.7951410877074239 and parameters: {'gb__learning_rate': 0.2141037086354206, 'gb__max_leaf_nodes': 205, 'gb__max_depth': 5, 'gb__min_samples_leaf': 63, 'gb__l2_regularization': 0.5320467637068419}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:32,407] Trial 92 finished with value: 0.7973878627602944 and parameters: {'gb__learning_rate': 0.20446122757709062, 'gb__max_leaf_nodes': 210, 'gb__max_depth': 5, 'gb__min_samples_leaf': 51, 'gb__l2_regularization': 0.8838866925337655}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:32,594] Trial 93 finished with value: 0.7960255501543687 and parameters: {'gb__learning_rate': 0.20747431563858057, 'gb__max_leaf_nodes': 206, 'gb__max_depth': 7, 'gb__min_samples_leaf': 18, 'gb__l2_regularization': 0.8835601828990001}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:32,870] Trial 94 finished with value: 0.7952679675473602 and parameters: {'gb__learning_rate': 0.19655235940600313, 'gb__max_leaf_nodes': 204, 'gb__max_depth': 7, 'gb__min_samples_leaf': 65, 'gb__l2_regularization': 1.1129886860565923}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:33,009] Trial 95 finished with value: 0.7957782750657394 and parameters: {'gb__learning_rate': 0.21451808567426536, 'gb__max_leaf_nodes': 207, 'gb__max_depth': 4, 'gb__min_samples_leaf': 18, 'gb__l2_regularization': 0.8897519581221458}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:33,144] Trial 96 finished with value: 0.7960945135048417 and parameters: {'gb__learning_rate': 0.20514727996020654, 'gb__max_leaf_nodes': 206, 'gb__max_depth': 7, 'gb__min_samples_leaf': 18, 'gb__l2_regularization': 0.5920059742572996}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:33,306] Trial 97 finished with value: 0.7965419702167076 and parameters: {'gb__learning_rate': 0.21027505008301559, 'gb__max_leaf_nodes': 204, 'gb__max_depth': 7, 'gb__min_samples_leaf': 19, 'gb__l2_regularization': 0.5680746899706937}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:33,448] Trial 98 finished with value: 0.7959314574950053 and parameters: {'gb__learning_rate': 0.19257269665113294, 'gb__max_leaf_nodes': 246, 'gb__max_depth': 7, 'gb__min_samples_leaf': 16, 'gb__l2_regularization': 0.489618643084753}. Best is trial 32 with value: 0.7987202222550611.
# [I 2026-03-13 01:55:34,415] Trial 99 finished with value: 0.7962486963302717 and parameters: {'gb__learning_rate': 0.03805356462943936, 'gb__max_leaf_nodes': 247, 'gb__max_depth': 7, 'gb__min_samples_leaf': 19, 'gb__l2_regularization': 0.9050200999875921}. Best is trial 32 with value: 0.7987202222550611.
#     Trial  F1_Score  gb__learning_rate  gb__max_leaf_nodes  gb__max_depth  \
# 32     32  0.798720           0.203160                 255              5
# 64     64  0.798151           0.101377                 230              5
# 92     92  0.797388           0.204461                 210              5
# 39     39  0.797378           0.259250                 256              4
# 75     75  0.797259           0.069420                 224              6
#
#     gb__min_samples_leaf  gb__l2_regularization
# 32                    13               1.065678
# 64                    42               1.067912
# 92                    51               0.883887
# 39                    10               1.342024
# 75                    42               0.696444

# %%
best_mean_f1_score = top_trials['F1_Score'].max()
best_mean_f1_score
# Out:
# np.float64(0.7987202222550611)

# %% [markdown]
# ### Problem 3 Graded Answer
#
# Set `a3` to the mean F1 score of the best model found.

# %%
 # Your answer here

a3 = best_mean_f1_score

# %%
# DO NOT change this cell in any way

print(f'a3 = {a3:.4f}')
# Out:
# a3 = 0.7987

# %% [markdown]
# ## Problem 4: Final Model Evaluation on Test Set
#
# In this problem, you will take the best hyperparameter configuration you found in your earlier experiments (Randomized Search or Optuna) and fully evaluate the resulting model on the test set.
#
# **Background:**
# When performing hyperparameter tuning, we typically optimize for a single metric (e.g., F1). However, before deployment, it is essential to check **all relevant metrics** on the final test set to understand the model’s behavior in a balanced way.
#
# **Instructions:**
#
# 1. Take the best hyperparameters you found in Problems 2 or 3 and apply them to your `pipelined_model`.
# 2. Re-train this final tuned model on the **entire training set** (not just the folds).
# 3. Evaluate the final model on the heldout **test set**, reporting the following metrics:
#
#    * Precision
#    * Recall
#    * F1 score
#    * Balanced accuracy
# 4. Use `classification_report` **on the test set** to print precision, recall, and F1 score, and use `balanced_accuracy_score` separately to calculate and print balanced accuracy.
# 5. Answer the graded questions.
#
# **Note:** We evaluate the metrics on the test set because it was never seen during training or hyperparameter tuning. This gives us an unbiased estimate of how the model will perform on truly unseen data. Evaluating on the training set would be misleading, because the model has already learned from that data and could appear artificially good.

# %%
# The best model identified via optuna hyper parameter tuning
best_model_params = top_trials.iloc[0].drop(labels=["Trial", "F1_Score"])

# Apply the best hyperparameters to the pipeline
best_params = {
    'gb__learning_rate': best_model_params['gb__learning_rate'],
    'gb__max_leaf_nodes': int(best_model_params['gb__max_leaf_nodes']),
    'gb__max_depth': int(best_model_params['gb__max_depth']),
    'gb__min_samples_leaf': int(best_model_params['gb__min_samples_leaf']),
    'gb__l2_regularization': best_model_params['gb__l2_regularization']
}

pipelined_model.set_params(**best_params)

# Re-train the model on the entire training set
pipelined_model.fit(X_train, y_train)

# Evaluate the model on the test set
y_pred = pipelined_model.predict(X_test)


# calculate metrics
balanced_acc = balanced_accuracy_score(y_test, y_pred)
macro_precision = classification_report(y_test, y_pred, output_dict=True)['macro avg']['precision']
macro_recall = classification_report(y_test, y_pred, output_dict=True)['macro avg']['recall']

print(f"Balanced Accuracy: {balanced_acc:.4f}")

report = classification_report(y_test, y_pred, target_names=['<=50K', '>50K'])
print("\nClassification Report:\n")
print(report)
# Out:
# Balanced Accuracy: 0.8454
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        <=50K       0.95      0.82      0.88      7431
#         >50K       0.61      0.87      0.71      2338
#
#     accuracy                           0.83      9769
#    macro avg       0.78      0.85      0.80      9769
# weighted avg       0.87      0.83      0.84      9769

# %% [markdown]
# ### Problem 4 Graded Questions
#
# - Set `a4a` to the balanced accuracy score of the best model.
# - Set `a4b` to the macro average precision of this model.
# - Set `a4c` to the macro average recall score of the this model.
#
# **Note:** Macro average takes the mean of each class’s precision/recall without considering how many samples each class has, which is appropriate for a balanced evaluation.

# %%
 # Your answer here

a4a = balanced_acc

# %%
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.8454

# %%
 # Your answer here

a4b = macro_precision

# %%
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.7791

# %%
 # Your answer here

a4c = macro_recall

# %%
# DO NOT change this cell in any way

print(f'a4c = {a4c:.4f}')
# Out:
# a4c = 0.8454

# %% [markdown]
# ## Problem 5: Understanding Precision, Recall, F1, and Balanced Accuracy
#
# **Tutorial**
#
# In binary classification, you will often evaluate these key metrics:
#
# * **Precision**: *Of all the positive predictions the model made, how many were actually correct?*
#
#   * High precision = few false positives
#   * Low precision = many false positives
#
# * **Recall**: *Of all the actual positive cases, how many did the model correctly identify?*
#
#   * High recall = few false negatives
#   * Low recall = many false negatives
#
# * **F1 score**: The harmonic mean of precision and recall, which balances them in a single measure.
#
#   * F1 is **highest** when precision and recall are both high and similar in value.
#   * If precision and recall are unbalanced, F1 will drop to reflect that imbalance.
#
# * **Balanced accuracy**: The average of recall across both classes (positive and negative).
#
#   * It ensures the classifier is performing reasonably well on *both* groups, correcting for class imbalance.
#   * Balanced accuracy is especially important if the classes are very unequal in size.
#
# **Typical trade-offs to remember:**
#
# * **Higher recall, lower precision**: the model finds most true positives but also mislabels some negatives as positives
# * **Higher precision, lower recall**: the model is strict about positive predictions, but misses some true positives
# * **Balanced precision and recall (good F1)**: a practical compromise
# * **Balanced accuracy**: checks fairness across both classes

# %% [markdown]
# ###  Problem 5 Graded Question (multiple choice)
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# (1) The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# (2) The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# (3) The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.

# %%
 # Your answer here

a5 = 2

# %%
# DO NOT change this cell in any way

print(f'a5 = {a5}')
# Out:
# a5 = 2

# %% [markdown]
# ### Appendix One: Feature Engineering
#
# Here are some practical feature-engineering tweaks worth considering (beyond simply ordinal-encoding the categoricals)
#
# | Feature(s)                                                           | Why the tweak can help                                                                                                                                                     | How to do it (quick version)                                                                                                                                                    | Keep / drop?      |
# | -------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------- |
# | **`fnlwgt`**                                                         | Survey sampling weight, not a predictor. Leaving it in often lets the model “cheat.”                                                                                       | `df = df.drop(columns=["fnlwgt"])`                                                                                                                                              | **Drop**          |
# | **`education` *vs.* `education-num`**                                | They encode the **same** information twice (categorical label and its ordinal rank). Keeping both is redundant and can cause leakage of a perfectly predictive feature.    | Usually keep **only one**. For tree models `education-num` is simplest: `df = df.drop(columns=["education"])`                                                                   | **Drop one**      |
# | **`capital-gain`, `capital-loss`**                                   | Highly skewed; most values are zero with a long upper tail. The sign (gain vs. loss) matters, but treating them separately wastes a feature slot.                          | 1) Combine: `df["capital_net"] = df["capital-gain"] - df["capital-loss"]`; 2) Log-transform to reduce skew: `df["capital_net_log"] = np.log1p(df["capital_net"].clip(lower=0))` | Replace originals |
# | **`age`, `hours-per-week`**                                          | Continuous but with natural plateaus—trees handle splits fine, yet log or square-root scaling can soften extreme values; bucketing makes partial-dependence plots clearer. | Simple bucket: `df["age_bin"] = pd.cut(df["age"], bins=[16,25,35,45,55,65,90])` (optional)                                                                                      | Optional          |
# | **Missing categories** (`workclass`, `occupation`, `native-country`) | HGB handles `-1`/`-2` codes fine, but you may want *explicit* “Missing” bucket for interpretability.                                                                       | Use `encoded_missing_value=-2` during encoding.                                                                                                            | Keep as is        |
# | **Rare categories in `native-country`**                              | Hundreds of low-frequency countries dilute signal; grouping boosts stability.                                                                                              | Map infrequent categories to “Other”:                                                                                                                                           |                   |
#
#
# #### Minimum set of tweaks (good baseline, low effort)
#
# 1. **Drop `fnlwgt`.**
# 2. **Keep `education-num`, drop `education`.**
# 3. **Combine `capital-gain` and `capital-loss` into `capital_net`** (optionally add a log-scaled version).
# 4. Leave other numeric/categorical features as is; your histogram-GBDT will cope.
